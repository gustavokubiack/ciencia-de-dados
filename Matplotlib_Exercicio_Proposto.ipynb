# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavokubiack/ciencia-de-dados/blob/main/Matplotlib_Exercicio_Proposto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/MyDrive/ciencia_de_dados/company_sales_data.csv")

# %% [markdown]
# # **Exercício 1: Leia o lucro total (total_profit) de todos os meses e mostre-o usando um gráfico de linhas**
#
# Dados de lucro total fornecidos para cada mês. O gráfico de linha gerado deve incluir as seguintes propriedades:
#
# *   **Label X = Número do mês**
# *   **Label Y = lucro total**

# %%
plt.plot(df['month_number'], df['total_profit'], color='b', marker='o', linewidth=2)

plt.xlabel('Número do mês')
plt.ylabel('Lucro total')
plt.title('Lucro total da empresa por mês')
plt.grid(True)
plt.show()

# %% [markdown]
# # **Exercício 2: Obtenha o lucro total de todos os meses e mostre o gráfico de linhas com as seguintes propriedades de estilo**
#
# O gráfico de linha gerado deve incluir as seguintes propriedades de estilo:
#
# *   O estilo da linha deve ser pontilhado e a cor da linha deve ser vermelha
# *   Mostrar legenda no canto inferior direito
# *   Label X = Número do mês
# *   Label Y = Número de unidades vendidas
# *   Adicione um marcador de círculo
# *   Cor do marcador de linha: preta
# *   A largura da linha deve ser 3

# %%
plt.plot(
    df['month_number'],
    df['total_units'],
    color='red',
    linestyle=':',
    marker='o',
    markerfacecolor='black',
    linewidth=3,
    label='Total de Unidades Vendidas'
)

plt.xlabel('Número do mês')
plt.ylabel('Número de unidades vendidas')
plt.title('Unidades vendidas por mês')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# # **Exercício 3: Leia todos os dados de vendas dos produtos e mostre-os usando um gráfico de várias linhas**
#
# **Exiba o número de unidades vendidas por mês para cada produto usando gráficos de várias linhas. Isto é, PlotLine separada para cada produto.**

# %%
produtos = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']

for produto in produtos:
    plt.plot(
        df['month_number'],
        df[produto],
        marker='o',
        linewidth=2,
        label=produto
    )

plt.xlabel('Número do mês')
plt.ylabel('Número de unidades vendidas')
plt.title('Vendas mensais por produto')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# # **Exercício 4: Leia os dados de vendas de creme dental de cada mês e mostre-os usando um gráfico de dispersão (scatter plot)**
#
# **Além disso, adicione uma grade no gráfico. O estilo da linha de grade deve ser “–“.**

# %%
plt.scatter(
    df['month_number'],
    df['toothpaste'],
    color='blue',
    marker='o',
    label='Toothpaste'
)

plt.xlabel('Número do mês')
plt.ylabel('Unidades vendidas de creme dental')
plt.title('Vendas mensais de creme dental')
plt.grid(True, linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# # **Exercício 5:  Leia os dados de vendas dos cremes faciais e produtos de lavagem facial e mostre-os usando o gráfico de barras**
#
# **O gráfico de barras deve exibir o número de unidades vendidas por mês para cada produto. Adicione uma barra separada para cada produto no mesmo gráfico.**

# %%
plt.bar(df['month_number']-0.2, df['facecream'], width=0.4, label='Facecream')
plt.bar(df['month_number']+0.2, df['facewash'], width=0.4, label='Facewash')

plt.xlabel('Número do mês')
plt.ylabel('Unidades vendidas')
plt.title('Vendas mensais de Facecream e Facewash')
plt.legend()
plt.show()

# %% [markdown]
# # **Exercício 6: Leia os dados de vendas dos sabonetes de todos os meses e mostre-os usando um gráfico de barras. Salve este gráfico em seu HD**

# %%
plt.bar(df['month_number'], df['bathingsoap'], color='green', label='Bathingsoap')
plt.xlabel('Número do mês')
plt.ylabel('Unidades vendidas')
plt.title('Vendas mensais de Bathingsoap')
plt.legend()
plt.savefig("bathingsoap_sales.png")
plt.show()

# %% [markdown]
# # **Exercício 7: Leia o lucro total de cada mês e mostre-o usando o histograma para ver as faixas de lucro mais comuns**

# %%
plt.hist(df['total_profit'], bins=10, color='purple', edgecolor='black')
plt.xlabel('Faixas de lucro')
plt.ylabel('Frequência')
plt.title('Distribuição do lucro total mensal')
plt.show()

# %% [markdown]
# # **Exercício 8: Calcule os dados de vendas totais do ano passado para cada produto e mostre-os usando um gráfico de pizza**

# %%
produtos = ['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
vendas_totais = df[produtos].sum()

plt.pie(vendas_totais, labels=produtos, autopct='%1.1f%%', startangle=90)
plt.title('Vendas totais anuais por produto')
plt.show()

# %% [markdown]
# # **Exercício 9: Leia os dados da Lavagem Facial e do Sabonete de todos os meses e exiba-o usando o SubPlot**

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8,6))

ax1.plot(df['month_number'], df['facewash'], color='blue', marker='o', label='Facewash')
ax1.set_title('Vendas mensais de Facewash')
ax1.set_xlabel('Número do mês')
ax1.set_ylabel('Unidades vendidas')
ax1.legend()
ax1.grid(True)

ax2.plot(df['month_number'], df['bathingsoap'], color='green', marker='o', label='Bathingsoap')
ax2.set_title('Vendas mensais de Bathingsoap')
ax2.set_xlabel('Número do mês')
ax2.set_ylabel('Unidades vendidas')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Exercício 10: Leia todos os dados de vendas de produtos e mostre-os usando o gráfico de pilha (stack plot)**

# %%
produtos = ['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']

plt.stackplot(df['month_number'], df[produtos].T, labels=produtos)

plt.xlabel('Número do mês')
plt.ylabel('Unidades vendidas')
plt.title('Vendas mensais acumuladas por produto (Stack Plot)')
plt.legend(loc='upper left')
plt.show()
